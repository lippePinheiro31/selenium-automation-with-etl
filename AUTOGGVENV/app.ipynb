# %%
##  https://docs.google.com/forms/d/e/1FAIpQLSe2FFVQ4bfdbrHT0zxx6oKAcdwsPPCe4by-_XXE0fESFNOh6Q/viewform?usp=publish-editor  ###








from selenium import webdriver
from time import sleep
from selenium.webdriver.common.keys import Keys
import chromedriver_autoinstaller
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

chromedriver_autoinstaller.install()

options = Options()
options.binary_location = r"C:\Users\santo\AppData\Local\Programs\Opera GX\opera.exe"
service = Service(r"C:\Users\santo\OneDrive\Desktop\AUTOGGFORM\chromedriver.exe")

browser = webdriver.Chrome(service=service, options=options)
link = "https://docs.google.com/forms/d/e/1FAIpQLSe2FFVQ4bfdbrHT0zxx6oKAcdwsPPCe4by-_XXE0fESFNOh6Q/viewform"
browser.get(link)


# browser = webdriver.Chrome()
# link = "https://docs.google.com/forms/d/e/1FAIpQLSe2FFVQ4bfdbrHT0zxx6oKAcdwsPPCe4by-_XXE0fESFNOh6Q/viewform"
# browser.get(link)

# %%
import pandas as pd

clients = pd.read_excel(r"C:\Users\santo\OneDrive\Desktop\AUTOGGFORM\AUTOGGVENV\data\dados_autoggform.xlsx")
#clients.head(5)

# %%
for index, row in clients.iterrows():  # index = indice identifica cada linha do nosso DF row = linha de cada passo
    NomeOrigin = row['nome']
    SobrenomeOrigin = row['']
    EmailOrigin = row['E-mail']
    CellphoneOrigin = row['Celular']
    StateOrigin = row['Estado']
    StreetOrigin = row['Rua']
    NumberOrigin = row['Número']
    additionalOrigin = row['Complemento']

    #preenchimento automático

    sleep(3)

    Nome = browser.find_element(by=By.XPATH, value='//*[@id="mG61Hd"]/div[2]/div/div[2]/div[1]/div/div/div[2]/div/div/div[1]/input').send_keys(NomeOrigin)
    Sobrenome = browser.find_element(by=By.XPATH, value='//*[@id="mG61Hd"]/div[2]/div/div[2]/div[2]/div/div/div[2]/div/div/div[1]/input').send_keys(SobrenomeOrigin)
    Email = browser.find_element(by=By.XPATH, value='//*[@id="mG61Hd"]/div[2]/div/div[2]/div[3]/div/div/div[2]/div/div/div[1]/input').send_keys(EmailOrigin)
    Celular = browser.find_element(by=By.XPATH, value='//*[@id="mG61Hd"]/div[2]/div/div[2]/div[4]/div/div/div[2]/div/div/div[1]/input').send_keys(CellphoneOrigin)
    Estado = browser.find_element(by=By.XPATH, value='//*[@id="mG61Hd"]/div[2]/div/div[2]/div[5]/div/div/div[2]/div/div/div[1]/input').send_keys(StateOrigin)
    Rua = browser.find_element(by=By.XPATH, value='//*[@id="mG61Hd"]/div[2]/div/div[2]/div[6]/div/div/div[2]/div/div/div[1]/input').send_keys(StreetOrigin)
    numero = browser.find_element(by=By.XPATH, value='//*[@id="mG61Hd"]/div[2]/div/div[2]/div[7]/div/div/div[2]/div/div/div[1]/input').send_keys(str(NumberOrigin))
    Complemento = browser.find_element(by=By.XPATH, value='//*[@id="mG61Hd"]/div[2]/div/div[2]/div[8]/div/div/div[2]/div/div/div[1]/input').send_keys(additionalOrigin)
    Enviar = browser.find_element(by=By.XPATH, value='//*[@id="mG61Hd"]/div[2]/div/div[3]/div[1]/div[1]/div/span/span').click()

    sleep(2)
    browser.get(link)
browser.quit()
